# %%
#Bài 1
a = float(input("Nhap canh a: "))
b = float(input("Nhap canh b: "))
print("Dien tich: ", a*b)
print("Chu vi: ", (a+b)*2)
# Out:
# Dien tich:  36.0
# Chu vi:  26.0

# %%
#bài 2
r = float(input("Nhap ban kinh r: "))
print("Dien tich hinh tron: ", 3.14*r*r)
print("Chu vi hinh tron: ", 2*3.14*r)
# Out:
# Dien tich hinh tron:  50.24
# Chu vi hinh tron:  25.12

# %%
#bài 3
a = float(input("Nhap canh a: "))
b = float(input("Nhap cạnh b: "))
c = float(input("Nhap canh c: "))
if a <= 0 or b <= 0 or c <= 0 or (a + b <= c) or (a + c <= b) or (b + c <= a):
    print("Khong la ba canh của tam giac")
else:
    print("La ba canh cua tam giac")
    if a == b == c:
        print("Tam giac deu")
    elif a == b or a == c or b == c:
        print(" Tam giac cân")
    elif (a*a + b*b == c*c) or (a*a + c*c == b*b) or (b*b + c*c == a*a):
        print(" Tam giac vuong")
    else:
        print(" Tam giac thuong")

    chu_vi = a + b + c
    p = chu_vi / 2
    dien_tich = (p * (p - a) * (p - b) * (p - c))

    print("Chu vi =", chu_vi)
    print("Dien tich =", dien_tich)
# Out:
# La ba canh cua tam giac
#  Tam giac vuong
# Chu vi = 12.0
# Dien tich = 36.0

# %%
#bài 4
a = float(input("Nhap he so a: "))
b = float(input("Nhap he so b: "))
if a == 0:
    if b == 0:
        print("Phuong trinh vo so nghiem.")
    else:
        print("Phuong trinh vo nghiem.")
else:
    x = -b / a
    print("Nghiem cua phuong trinh la x =", x)
# Out:
# Nghiem cua phuong trinh la x = -1.6666666666666667

# %%
#Bài 5
a, b, c = map(float, input("Nhap vao 3 so: ").split())
delta = b*b - 4*a*c
if delta < 0:
    print("Phuong trinh vo nghiem.")
elif delta == 0:
    x = -b / (2*a)
    print("Phuong trinh co nghiem kep x =", x)
else:
    x1 = (-b + delta**0.5) / (2*a)
    x2 = (-b - delta**0.5) / (2*a)
    print("Phuong trinh co 2 nghiem phan biet:")
    print("x1 =", x1)
    print("x2 =", x2)
# Out:
# Phuong trinh vo nghiem.

# %%
#Bài 6
a, b, c, d = map(float, input("Nhap vao 4 so: ").split())

x = max(a, b, c, d)
print("so lon nhat:", x)
# Out:
# so lon nhat: 8.0

# %%
#Bài 7
a, b, c, d = map(float, input("Nhap vao 4 so: ").split())

x = min(a, b, c, d)
print("so nho nhat:", x)
# Out:
# so nho nhat: 4.0

# %%
#Bài 9
x=int(input("Nhap vao so giay: "))
gio=x/3600
x=x%3600
phut=x/60
giay=x%60
print(x, "giay tuong duong voi ", gio, "gio", phut, "phut", giay, "giay")
# Out:
# 60 giay tuong duong voi  0.016666666666666666 gio 1.0 phut 0 giay

# %%
#bài 11\
x, y = map(float, input("nhap vao 2 so thuc: ").split())
print(x**y)
# Out:
# 81.0
